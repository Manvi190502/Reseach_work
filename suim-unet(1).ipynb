# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_602_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1428_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1282_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_93_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_59_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1992_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1461_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_101_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_379_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_598_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1303_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1737_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_552_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_24_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_111_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_79_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1059_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_100_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_144_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_29_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1440_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_102_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_4_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1220_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1892_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_345_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_604_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_199_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_116_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_54_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_6_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_122_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1298_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_263_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_478_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1319_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1033_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_217_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1276_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1800_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_18_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_201_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1199_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1478_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_3_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_109_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1920_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1471_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_43_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_3_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1644_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1948_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_10_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_157_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_386_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_403_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1229_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1965_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_465_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_12_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_106_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_384_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_209_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_22_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_147_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1450_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_644_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_15_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_182_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1435_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1931_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_47_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_721_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_84_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_166_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_246_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_547_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_30_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_392_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_14_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1410_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_300_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_2052_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_801_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_84_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_50_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1079_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_48_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_329_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_233_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_44_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_58_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_446_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_277_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_84_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1340_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_13_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_214_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_129_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/w_r_150_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_26_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_52_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1165_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1467_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_87_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/n_l_0_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_635_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1782_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/d_r_196_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/images/f_r_1452_.jpg
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_54_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1298_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_465_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_43_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1992_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_147_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_182_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_44_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_446_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_59_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_109_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_93_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1471_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_552_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1461_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_18_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1319_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1033_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1079_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1282_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_24_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_106_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_79_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_102_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_116_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_263_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1737_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_300_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_30_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1410_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_384_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_150_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_101_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1220_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1340_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_246_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1931_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_345_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_547_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_144_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_801_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1467_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_14_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1303_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_233_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_13_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1965_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_50_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_15_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_277_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1452_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_386_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_329_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_209_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1276_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_201_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1800_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_0_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_602_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_29_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_635_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_58_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1229_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_47_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_196_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_26_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_22_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1948_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_6_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_166_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1435_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_129_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_379_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1892_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1165_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_100_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_2052_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1450_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_12_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_392_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_604_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_217_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_87_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_214_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_4_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_52_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1428_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_10_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_403_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1440_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1059_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_598_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1782_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_157_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_1920_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/n_l_48_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/d_r_122_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/w_r_111_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/f_r_721_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_54_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1298_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_465_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_43_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1992_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_147_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_182_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_44_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_446_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_59_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_109_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_93_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1471_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_552_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1461_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_18_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1319_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1033_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1079_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1282_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_24_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_106_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_79_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_102_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_116_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_263_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1737_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_300_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_30_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1410_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_384_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_150_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_101_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1220_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1340_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_246_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1931_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_345_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_547_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_144_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_801_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1467_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_14_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1303_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_233_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_13_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1965_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_50_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_15_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_277_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1452_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_386_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_329_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_209_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1276_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_201_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1800_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_0_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_602_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_29_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_635_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_58_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1229_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_47_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_196_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_26_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_22_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1948_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_6_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_166_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1435_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_129_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_379_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1892_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1165_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_100_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_2052_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1450_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_12_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_392_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_604_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_217_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_87_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_214_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_4_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_52_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1428_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_10_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_403_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1440_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1059_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_598_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1782_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_157_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_1920_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/n_l_48_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/d_r_122_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/w_r_111_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/FV/f_r_721_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_54_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1298_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_465_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_43_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1992_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_147_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_182_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_44_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_446_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_59_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_109_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_93_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1471_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_552_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1461_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_18_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1319_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1033_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1079_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1282_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_24_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_106_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_79_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_102_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_116_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_263_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1737_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_300_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_30_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1410_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_384_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_150_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_101_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1220_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1340_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_246_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1931_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_345_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_547_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_144_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_801_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1467_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_14_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1303_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_233_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_13_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1965_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_50_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_15_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_277_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1452_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_386_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_329_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_209_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1276_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_201_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1800_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_0_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_602_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_29_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_635_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_58_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1229_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_47_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_196_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_26_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_22_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1948_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_6_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_166_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1435_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_129_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_379_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1892_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1165_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_100_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_2052_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1450_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_12_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_392_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_604_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_217_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_87_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_214_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_4_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_52_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1428_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_10_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_403_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1440_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1059_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_598_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1782_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_157_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_1920_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/n_l_48_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/d_r_122_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/w_r_111_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/RO/f_r_721_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_54_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1298_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_465_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_43_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1992_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_147_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_182_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_44_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_446_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_59_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_109_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_93_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1471_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_552_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1461_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_18_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1319_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1033_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1079_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1282_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_24_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_106_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_79_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1644_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_102_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_116_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_263_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1737_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_300_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_30_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1410_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_384_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_150_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_101_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1220_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1340_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_246_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1931_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_345_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_547_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_144_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_801_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1467_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_14_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1303_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_233_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_13_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1965_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_50_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_15_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_277_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1452_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_386_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_329_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_209_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1276_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_201_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1800_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_0_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_602_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_29_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_635_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_58_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1229_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1478_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_47_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_196_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_26_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_22_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1948_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1199_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_6_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_166_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1435_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_129_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/d_r_379_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1892_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1165_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_100_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_2052_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1450_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_12_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_392_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_84_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_604_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_217_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_87_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_214_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_4_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/n_l_52_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1428_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/w_r_10_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_403_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST/masks/PF/f_r_1440_.bmp
# ...
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_2041_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_246_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_245_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_444_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1740_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_469_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_476_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_627_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1291_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1518_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_295_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_541_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_620_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_377_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_764_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_754_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1401_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_745_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_29_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1530_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1459_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1833_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1730_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1724_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1973_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1088_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1109_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_616_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_406_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_568_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_919_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_526_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1921_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1144_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_166_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_961_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1369_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_266_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_227_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1553_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_43_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_759_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_622_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1335_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_30_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_18_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1447_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1841_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_510_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_520_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1545_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_280_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_640_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_712_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_248_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1947_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1957_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_729_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1774_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_564_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1238_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1387_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_3_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_738_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1809_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_814_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1042_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1020_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_842_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_372_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_293_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_383_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_436_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_223_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_25_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1300_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_5_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_514_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_171_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1197_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1865_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1900_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1050_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1007_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_225_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1193_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_230_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1265_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1502_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1911_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1152_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_224_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_969_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_480_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_34_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_223_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_37_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1538_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1709_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_45_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1816_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_23_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1175_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_486_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_89_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1912_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_846_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1556_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_126_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_175_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_236_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1274_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_630_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_237_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_347_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1081_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_2005_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_851_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_376_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1943_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1019_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_132_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1200_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_188_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_618_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_27_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1897_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1214_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1315_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1946_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1569_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_112_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_655_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1622_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_271_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_41_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1891_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_179_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_613_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_903_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_61_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1696_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1551_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_98_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1623_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_27_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1550_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_17_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/d_r_682_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1582_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_96_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_366_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_18_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1660_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1013_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1685_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1347_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1951_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_97_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1249_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_218_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1678_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_289_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_165_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_191_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_2075_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/n_l_93_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1044_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_173_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_100_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/w_r_64_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_1147_.bmp
# /kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val/masks/f_r_172_.bmp

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from tensorflow.keras.layers import *
# Out:
# 2025-09-01 12:19:09.722708: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756729150.076444      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756729150.173171      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
color_map = {
    (0, 0, 0): 0,        # BW
    (0, 0, 255): 1,      # HD 
    (0, 255, 0): 2,      # PF 
    (255, 255, 0): 3,    # WR 
    (0, 0, 128): 4,      # RO 
    (255, 0, 255): 5,    # RI 
    (0, 255, 255): 6,    # FV 
    (255, 255, 255): 7   # SR
}

# %%
index_to_color = {
    0: (0, 0, 0),
    1: (0, 0, 255),
    2: (0, 255, 0),
    3: (255, 255, 0),
    4: (0, 0, 128),
    5: (255, 0, 255),
    6: (0, 255, 255),
    7: (255, 255, 255)
}

# %%
def load_data(image_dir, mask_dir, image_size=(256, 256)):
    image_paths = []
    mask_paths = []
    
    for filename in os.listdir(os.path.join(image_dir, "images")):
        if filename.endswith(".jpg"):
            base_name = os.path.splitext(filename)[0]
            img_path = os.path.join(image_dir, "images", filename)
            mask_path = os.path.join(mask_dir, "masks", base_name + ".bmp")
            
            if os.path.exists(mask_path):
                image_paths.append(img_path)
                mask_paths.append(mask_path)
    
    return image_paths, mask_paths


def get_augmentation():
    return A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.ShiftScaleRotate(
            shift_limit=0.0625,
            scale_limit=0.1,
            rotate_limit=25,
            interpolation=cv2.INTER_LINEAR,
            mask_interpolation=cv2.INTER_NEAREST,
            p=0.5
        ),
        A.GridDistortion(
            num_steps=5,
            distort_limit=0.3,
            interpolation=cv2.INTER_LINEAR,
            mask_interpolation=cv2.INTER_NEAREST,
            p=0.2
        ),
        A.RandomBrightnessContrast(
            brightness_limit=0.2,
            contrast_limit=0.2,
            p=0.3
        )
    ], additional_targets={'mask': 'image'})

def data_generator(image_paths, mask_paths, batch_size=8, image_size=(256, 256)):
    aug = get_augmentation()
    while True:
        indices = np.random.permutation(len(image_paths))
        for i in range(0, len(indices), batch_size):
            batch_indices = indices[i:i+batch_size]
            batch_images = []
            batch_masks = []
            
            for j in batch_indices:
                img = cv2.imread(image_paths[j])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # BGR转RGB
                img = cv2.resize(img, image_size)
                img = img.astype(np.float32) / 255.0
                
                mask = cv2.imread(mask_paths[j])
                mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)  # BGR转RGB
                mask = cv2.resize(mask, image_size, interpolation=cv2.INTER_NEAREST)

                augmented = aug(image=img, mask=mask)
                img_aug = augmented['image']
                mask_aug = augmented['mask']
                
                class_mask = np.zeros(mask_aug.shape[:2], dtype=np.uint8)
                for color, idx in color_map.items():
                    class_mask[np.all(mask_aug == color, axis=-1)] = idx
                
                batch_images.append(img_aug)
                batch_masks.append(class_mask)
            
            yield np.array(batch_images), np.array(batch_masks)

# %%
def unet_model(input_size=(256, 256, 3), num_classes=8):
    inputs = Input(input_size)
    
    c1 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(inputs)
    c1 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c1)
    p1 = MaxPooling2D((2,2))(c1)
    
    c2 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(p1)
    c2 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c2)
    p2 = MaxPooling2D((2,2))(c2)
    
    c3 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(p2)
    c3 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c3)
    p3 = MaxPooling2D((2,2))(c3)
    
    c4 = Conv2D(512, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(p3)
    c4 = Conv2D(512, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c4)
    
    u5 = UpSampling2D((2,2))(c4)
    u5 = concatenate([u5, c3])
    c5 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(u5)
    c5 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c5)
    
    u6 = UpSampling2D((2,2))(c5)
    u6 = concatenate([u6, c2])
    c6 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(u6)
    c6 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c6)
    
    u7 = UpSampling2D((2,2))(c6)
    u7 = concatenate([u7, c1])
    c7 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(u7)
    c7 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c7)
    
    outputs = Conv2D(num_classes, (1,1), activation='softmax')(c7)
    
    model = Model(inputs=inputs, outputs=outputs)
 
   # model.compile(optimizer=Adam(learning_rate=1e-4),
    #         loss=sparse_combined_loss,
     #        metrics=['accuracy'])

    return model

# %%
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 5
EPOCHS = 75


train_image_dir = "/kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val"
train_mask_dir = "/kaggle/input/semantic-segmentation-of-underwater-imagery-suim/train_val"
test_image_dir = "/kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST"
test_mask_dir = "/kaggle/input/semantic-segmentation-of-underwater-imagery-suim/TEST"

train_image_paths, train_mask_paths = load_data(train_image_dir, train_mask_dir)
test_image_paths, test_mask_paths = load_data(test_image_dir, test_mask_dir)

train_img, val_img, train_msk, val_msk = train_test_split(
    train_image_paths, train_mask_paths, test_size=0.2, random_state=42)

# %%
def sparse_combined_loss(y_true, y_pred, alpha=0.5, num_classes=8):
    ce_loss = tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)
    
    y_true_oh = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
    y_pred_oh = tf.nn.softmax(y_pred)
    
    intersection = tf.reduce_sum(y_true_oh * y_pred_oh, axis=[1,2])
    union = tf.reduce_sum(y_true_oh + y_pred_oh, axis=[1,2])
    dice_loss = 1 - tf.reduce_mean((2. * intersection + 1e-7)/(union + 1e-7))
    
    gamma = 2.0
    focal_loss = tf.reduce_mean(-(1-y_pred_oh)**gamma * tf.math.log(y_pred_oh + 1e-7))
    
    return alpha*ce_loss + (0.5-alpha)*dice_loss + 0.2*focal_loss

# %%
def calculate_metrics(true_mask, pred_mask, num_classes):

    dice = np.zeros(num_classes)
    iou = np.zeros(num_classes)
    f1 = np.zeros(num_classes)
    
    for cls in range(num_classes):
        true_cls = (true_mask == cls)
        pred_cls = (pred_mask == cls)
        
        intersection = np.logical_and(true_cls, pred_cls).sum()
        union = np.logical_or(true_cls, pred_cls).sum()
        true_sum = true_cls.sum()
        pred_sum = pred_cls.sum()
        
        dice[cls] = (2. * intersection) / (true_sum + pred_sum + 1e-7)
        
        # IoU
        iou[cls] = intersection / (union + 1e-7)
        
        # F1
        precision = intersection / (pred_sum + 1e-7)
        recall = intersection / (true_sum + 1e-7)
        f1[cls] = 2 * (precision * recall) / (precision + recall + 1e-7)
    
    return dice, iou, f1

# %%
def visualize_results(image_path, mask_path, model, size=(256,256)):
    # 1.（BGR→RGB）
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    orig_size = img.shape[:2]
    img = cv2.resize(img, size)
    img_input = img.astype(np.float32)/255.0
    img_input = np.expand_dims(img_input, axis=0)
    
    # 2. predict
    pred = model.predict(img_input)[0]
    pred_mask = np.argmax(pred, axis=-1)
    
    # 3. mask（BGR→RGB）
    true_mask = cv2.imread(mask_path)
    true_mask = cv2.cvtColor(true_mask, cv2.COLOR_BGR2RGB)  
    true_mask = cv2.resize(true_mask, size, interpolation=cv2.INTER_NEAREST)
    
    true_class = np.zeros(true_mask.shape[:2], dtype=np.uint8)
    for color, idx in color_map.items(): 
        true_class[np.all(true_mask == color, axis=-1)] = idx
    
    
    pred_color = np.zeros((*size, 3), dtype=np.uint8)
    true_color = np.zeros((*size, 3), dtype=np.uint8)
    
    for idx, color in index_to_color.items():  
        pred_color[pred_mask == idx] = color
        true_color[true_class == idx] = color
    
   
    plt.figure(figsize=(15,5))
    plt.subplot(1,3,1)
    plt.imshow(img) 
    plt.title("Original Image")
    
    plt.subplot(1,3,2)
    plt.imshow(true_color)
    plt.title("True Mask")
    
    plt.subplot(1,3,3)
    plt.imshow(pred_color)
    plt.title("Predicted Mask")
    plt.show()

# %%
train_gen = data_generator(train_img, train_msk, BATCH_SIZE, IMAGE_SIZE)
val_gen = data_generator(val_img, val_msk, BATCH_SIZE, IMAGE_SIZE)


model = unet_model(input_size=IMAGE_SIZE + (3,))

model.compile(optimizer=Adam(learning_rate=1e-4),
              loss=sparse_combined_loss,
             metrics=['accuracy']
             )
model.summary()
# Out:
# I0000 00:00:1756729166.273902      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1756729166.274703      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 64,    │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 768)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │  1,769,728 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 128,  │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 384)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 256, 256,  │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │        520 │ conv2d_13[0][0]   │
# │                     │ 8)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,783,368 (29.69 MB)
#  Trainable params: 7,783,368 (29.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_gen,
    steps_per_epoch=len(train_img)//BATCH_SIZE,
    validation_data=val_gen,
    validation_steps=len(val_img)//BATCH_SIZE,
    epochs=EPOCHS
)

val_dice = []
val_iou = []
val_f1 = []

for i in range(len(val_img)//BATCH_SIZE):
    x_val, y_val = next(val_gen)
    y_pred = model.predict(x_val)
    y_pred = np.argmax(y_pred, axis=-1)
    
    for j in range(len(y_val)):
        true_mask = y_val[j]
        pred_mask = y_pred[j]
        dice, iou, f1 = calculate_metrics(true_mask, pred_mask, num_classes=len(index_to_color))
        val_dice.append(dice)
        val_iou.append(iou)
        val_f1.append(f1)

avg_val_dice = np.mean(val_dice, axis=0)
avg_val_iou = np.mean(val_iou, axis=0)
avg_val_f1 = np.mean(val_f1, axis=0)

class_names = list(index_to_color.keys())
for cls, name in enumerate(class_names):
    print(f"Class {name}:")
    print(f"  Dice: {avg_val_dice[cls]:.4f}")
    print(f"  IoU: {avg_val_iou[cls]:.4f}")
    print(f"  F1: {avg_val_f1[cls]:.4f}")
    print()

mIoU = np.mean(avg_val_iou)
avg_dice = np.mean(avg_val_dice)
print(f"mIoU: {mIoU:.4f}")
print(f"Average Dice: {avg_dice:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/75
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756729175.842527     104 service.cc:148] XLA service 0x799f60014170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1756729175.844086     104 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1756729175.844106     104 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# W0000 00:00:1756729176.280060     104 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_combined_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# I0000 00:00:1756729176.647880     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-09-01 12:19:40.563840: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng12{k11=0} for conv (f32[5,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-09-01 12:19:40.593995: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.030344s
# Trying algorithm eng12{k11=0} for conv (f32[5,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# E0000 00:00:1756729189.911805     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1756729190.205129     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1756729193.391366     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1756729193.612267     104 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1756729205.363217     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.5229 - loss: 1.0608
# W0000 00:00:1756729280.448141     104 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_combined_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 138s 416ms/step - accuracy: 0.5231 - loss: 1.0606 - val_accuracy: 0.5646 - val_loss: 0.9560
# Epoch 2/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6066 - loss: 0.9322 - val_accuracy: 0.5886 - val_loss: 0.9309
# Epoch 3/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.5932 - loss: 0.9375 - val_accuracy: 0.5778 - val_loss: 0.9290
# Epoch 4/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.5883 - loss: 0.9334 - val_accuracy: 0.6137 - val_loss: 0.9163
# Epoch 5/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.5994 - loss: 0.9175 - val_accuracy: 0.6056 - val_loss: 0.8950
# Epoch 6/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 293ms/step - accuracy: 0.6069 - loss: 0.8981 - val_accuracy: 0.6057 - val_loss: 0.8851
# Epoch 7/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 293ms/step - accuracy: 0.6063 - loss: 0.8884 - val_accuracy: 0.6073 - val_loss: 0.9213
# Epoch 8/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6130 - loss: 0.8854 - val_accuracy: 0.6187 - val_loss: 0.9044
# Epoch 9/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6054 - loss: 0.8848 - val_accuracy: 0.6140 - val_loss: 0.8703
# Epoch 10/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6164 - loss: 0.8711 - val_accuracy: 0.6053 - val_loss: 0.8897
# Epoch 11/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6315 - loss: 0.8586 - val_accuracy: 0.6320 - val_loss: 0.8550
# Epoch 12/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6199 - loss: 0.8628 - val_accuracy: 0.6223 - val_loss: 0.8567
# Epoch 13/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6203 - loss: 0.8584 - val_accuracy: 0.6276 - val_loss: 0.8462
# Epoch 14/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 293ms/step - accuracy: 0.6155 - loss: 0.8691 - val_accuracy: 0.6079 - val_loss: 0.8712
# Epoch 15/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6259 - loss: 0.8488 - val_accuracy: 0.6265 - val_loss: 0.8406
# Epoch 16/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6343 - loss: 0.8421 - val_accuracy: 0.6225 - val_loss: 0.8493
# Epoch 17/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6220 - loss: 0.8490 - val_accuracy: 0.6297 - val_loss: 0.8425
# Epoch 18/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6391 - loss: 0.8284 - val_accuracy: 0.6436 - val_loss: 0.8234
# Epoch 19/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6335 - loss: 0.8353 - val_accuracy: 0.6410 - val_loss: 0.8217
# Epoch 20/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6381 - loss: 0.8258 - val_accuracy: 0.5914 - val_loss: 0.8651
# Epoch 21/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6293 - loss: 0.8340 - val_accuracy: 0.6580 - val_loss: 0.8277
# Epoch 22/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6122 - loss: 0.8512 - val_accuracy: 0.6316 - val_loss: 0.8271
# Epoch 23/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6337 - loss: 0.8293 - val_accuracy: 0.6257 - val_loss: 0.8324
# Epoch 24/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6306 - loss: 0.8296 - val_accuracy: 0.6157 - val_loss: 0.8350
# Epoch 25/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6449 - loss: 0.8184 - val_accuracy: 0.6487 - val_loss: 0.8177
# Epoch 26/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6317 - loss: 0.8213 - val_accuracy: 0.6631 - val_loss: 0.8019
# Epoch 27/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6559 - loss: 0.8035 - val_accuracy: 0.6456 - val_loss: 0.8094
# Epoch 28/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 70s 289ms/step - accuracy: 0.6560 - loss: 0.8097 - val_accuracy: 0.6586 - val_loss: 0.7975
# Epoch 29/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6324 - loss: 0.8235 - val_accuracy: 0.6715 - val_loss: 0.8112
# Epoch 30/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6562 - loss: 0.8070 - val_accuracy: 0.6562 - val_loss: 0.8030
# Epoch 31/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6575 - loss: 0.7974 - val_accuracy: 0.6613 - val_loss: 0.7946
# Epoch 32/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 289ms/step - accuracy: 0.6590 - loss: 0.7945 - val_accuracy: 0.6602 - val_loss: 0.8050
# Epoch 33/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6445 - loss: 0.8063 - val_accuracy: 0.6712 - val_loss: 0.7948
# Epoch 34/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6622 - loss: 0.7942 - val_accuracy: 0.6439 - val_loss: 0.8059
# Epoch 35/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6469 - loss: 0.8104 - val_accuracy: 0.6677 - val_loss: 0.7908
# Epoch 36/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6607 - loss: 0.7887 - val_accuracy: 0.6526 - val_loss: 0.7931
# Epoch 37/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6826 - loss: 0.7628 - val_accuracy: 0.6600 - val_loss: 0.8035
# Epoch 38/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6642 - loss: 0.7784 - val_accuracy: 0.6588 - val_loss: 0.7972
# Epoch 39/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6575 - loss: 0.7896 - val_accuracy: 0.6493 - val_loss: 0.8003
# Epoch 40/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6608 - loss: 0.7855 - val_accuracy: 0.6542 - val_loss: 0.7926
# Epoch 41/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6692 - loss: 0.7809 - val_accuracy: 0.6731 - val_loss: 0.7804
# Epoch 42/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6552 - loss: 0.7909 - val_accuracy: 0.6682 - val_loss: 0.7838
# Epoch 43/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6714 - loss: 0.7784 - val_accuracy: 0.6756 - val_loss: 0.7746
# Epoch 44/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6784 - loss: 0.7755 - val_accuracy: 0.6584 - val_loss: 0.7987
# Epoch 45/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6676 - loss: 0.7830 - val_accuracy: 0.6766 - val_loss: 0.7729
# Epoch 46/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6597 - loss: 0.7803 - val_accuracy: 0.6859 - val_loss: 0.7786
# Epoch 47/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6767 - loss: 0.7727 - val_accuracy: 0.6607 - val_loss: 0.7967
# Epoch 48/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6767 - loss: 0.7647 - val_accuracy: 0.6699 - val_loss: 0.7901
# Epoch 49/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6693 - loss: 0.7681 - val_accuracy: 0.6817 - val_loss: 0.7670
# Epoch 50/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6928 - loss: 0.7475 - val_accuracy: 0.6696 - val_loss: 0.7702
# Epoch 51/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6708 - loss: 0.7708 - val_accuracy: 0.6855 - val_loss: 0.7694
# Epoch 52/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6894 - loss: 0.7519 - val_accuracy: 0.6814 - val_loss: 0.7705
# Epoch 53/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6850 - loss: 0.7584 - val_accuracy: 0.6553 - val_loss: 0.7826
# Epoch 54/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6791 - loss: 0.7674 - val_accuracy: 0.6598 - val_loss: 0.7841
# Epoch 55/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6813 - loss: 0.7602 - val_accuracy: 0.6263 - val_loss: 0.8151
# Epoch 56/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6809 - loss: 0.7622 - val_accuracy: 0.6658 - val_loss: 0.7905
# Epoch 57/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6860 - loss: 0.7552 - val_accuracy: 0.6724 - val_loss: 0.7759
# Epoch 58/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6901 - loss: 0.7486 - val_accuracy: 0.6862 - val_loss: 0.7616
# Epoch 59/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6786 - loss: 0.7618 - val_accuracy: 0.6702 - val_loss: 0.7768
# Epoch 60/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6979 - loss: 0.7465 - val_accuracy: 0.6593 - val_loss: 0.7858
# Epoch 61/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6771 - loss: 0.7621 - val_accuracy: 0.6818 - val_loss: 0.7769
# Epoch 62/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6994 - loss: 0.7427 - val_accuracy: 0.6766 - val_loss: 0.7649
# Epoch 63/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6830 - loss: 0.7578 - val_accuracy: 0.6677 - val_loss: 0.7670
# Epoch 64/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6948 - loss: 0.7466 - val_accuracy: 0.6857 - val_loss: 0.7687
# Epoch 65/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6914 - loss: 0.7553 - val_accuracy: 0.6802 - val_loss: 0.7844
# Epoch 66/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6846 - loss: 0.7548 - val_accuracy: 0.6915 - val_loss: 0.7559
# Epoch 67/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6790 - loss: 0.7575 - val_accuracy: 0.6848 - val_loss: 0.7570
# Epoch 68/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.7065 - loss: 0.7322 - val_accuracy: 0.6883 - val_loss: 0.7525
# Epoch 69/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 291ms/step - accuracy: 0.6782 - loss: 0.7496 - val_accuracy: 0.6784 - val_loss: 0.7731
# Epoch 71/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6967 - loss: 0.7469 - val_accuracy: 0.6748 - val_loss: 0.7624
# Epoch 72/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6944 - loss: 0.7373 - val_accuracy: 0.6860 - val_loss: 0.7639
# Epoch 73/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6990 - loss: 0.7365 - val_accuracy: 0.6807 - val_loss: 0.7635
# Epoch 74/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 290ms/step - accuracy: 0.6864 - loss: 0.7456 - val_accuracy: 0.6846 - val_loss: 0.7587
# Epoch 75/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 70s 289ms/step - accuracy: 0.6833 - loss: 0.7497 - val_accuracy: 0.6797 - val_loss: 0.7590
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Class 0:
#   Dice: 0.6934
#   IoU: 0.5995
#   F1: 0.6934
#
# Class 1:
#   Dice: 0.0918
#   IoU: 0.0708
#   F1: 0.0918
#
# Class 2:
#   Dice: 0.0039
#   IoU: 0.0025
#   F1: 0.0039
#
# Class 3:
#   Dice: 0.2591
#   IoU: 0.1883
#   F1: 0.2591
#
# Class 4:
#   Dice: 0.0000
#   IoU: 0.0000
#   F1: 0.0000
#
# Class 5:
#   Dice: 0.4273
#   IoU: 0.3651
#   F1: 0.4273
#
# Class 6:
#   Dice: 0.0508
#   IoU: 0.0373
#   F1: 0.0508
#
# Class 7:
#   Dice: 0.1633
#   IoU: 0.1256
#   F1: 0.1633
#
# mIoU: 0.1736
# Average Dice: 0.2112

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()


plt.subplot(1, 3, 3)
plt.bar(class_names, avg_val_dice)
plt.title('Dice Coefficient per Class')
plt.ylabel('Dice')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

plt.figure(figsize=(12, 4))

# IoU
plt.subplot(1, 2, 1)
plt.bar(class_names, avg_val_iou)
plt.title('IoU per Class')
plt.ylabel('IoU')
plt.xticks(rotation=45)

# F1
plt.subplot(1, 2, 2)
plt.bar(class_names, avg_val_f1)
plt.title('F1 Score per Class')
plt.ylabel('F1 Score')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
for i in np.random.choice(len(test_image_paths), 3):
    visualize_results(test_image_paths[i], test_mask_paths[i], model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %% [markdown]
# UNET + SE

# %%
def se_block(input_tensor, ratio=16):
    channels = input_tensor.shape[-1]
    se_shape = (1, 1, channels)
    
    se = GlobalAveragePooling2D()(input_tensor)
    se = Reshape(se_shape)(se)
    
    se = Dense(channels // ratio, activation='relu', kernel_initializer='he_normal')(se)
    se = Dense(channels, activation='sigmoid', kernel_initializer='he_normal')(se)
    
    return Multiply()([input_tensor, se])

# %%
def attention_unet_model(input_size=(256, 256, 3), num_classes=8):
    inputs = Input(input_size)
    
    # Block 1
    c1 = Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    s1 = se_block(c1)  
    p1 = MaxPooling2D((2,2))(s1)
    
    # Block 2
    c2 = Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    s2 = se_block(c2) 
    p2 = MaxPooling2D((2,2))(s2)
    
    # Block 3
    c3 = Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3,3), activation='relu', padding='same')(c3)
    s3 = se_block(c3)  
    p3 = MaxPooling2D((2,2))(s3)

    # Block 4
    c4 = Conv2D(512, (3,3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3,3), activation='relu', padding='same')(c4)
    s4 = se_block(c4) 

    # Block 5
    u5 = UpSampling2D((2,2))(s4)
    u5 = concatenate([u5, s3])
    c5 = Conv2D(256, (3,3), activation='relu', padding='same')(u5)
    c5 = Conv2D(256, (3,3), activation='relu', padding='same')(c5)
    
    # Block 6
    u6 = UpSampling2D((2,2))(c5)
    u6 = concatenate([u6, s2]) 
    c6 = Conv2D(128, (3,3), activation='relu', padding='same')(u6)
    c6 = Conv2D(128, (3,3), activation='relu', padding='same')(c6)
    
    # Block 7
    u7 = UpSampling2D((2,2))(c6)
    u7 = concatenate([u7, s1])
    c7 = Conv2D(64, (3,3), activation='relu', padding='same')(u7)
    c7 = Conv2D(64, (3,3), activation='relu', padding='same')(c7)
    
    outputs = Conv2D(num_classes, (1,1), activation='softmax')(c7)
    
    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
model_se = attention_unet_model(input_size=IMAGE_SIZE + (3,))

model_se.compile(optimizer=Adam(learning_rate=1e-4),
              loss=sparse_combined_loss,
             metrics=['accuracy']
             )
model_se.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 256, 256,  │      1,792 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_15[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_16[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 64)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 4)   │        260 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 64)  │        320 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 256, 256,  │          0 │ conv2d_16[0][0],  │
# │                     │ 64)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 128, 128,  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     73,856 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_17[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_18[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1, 1, 8)   │      1,032 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1, 1, 128) │      1,152 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 128, 128,  │          0 │ conv2d_18[0][0],  │
# │ (Multiply)          │ 128)              │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 64, 64,    │    295,168 │ max_pooling2d_4[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_19[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_20[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 256) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1, 1, 16)  │      4,112 │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1, 1, 256) │      4,352 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ conv2d_20[0][0],  │
# │ (Multiply)          │ 256)              │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ multiply_2[0][0]  │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_5[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_21[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ conv2d_22[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 512) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1, 1, 32)  │     16,416 │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1, 1, 512) │     16,896 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 32, 32,    │          0 │ conv2d_22[0][0],  │
# │ (Multiply)          │ 512)              │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 64, 64,    │          0 │ multiply_3[0][0]  │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 768)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 64, 64,    │  1,769,728 │ concatenate_3[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_23[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ conv2d_24[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 128, 128,  │          0 │ up_sampling2d_4[… │
# │ (Concatenate)       │ 384)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_25[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 256, 256,  │          0 │ conv2d_26[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 256, 256,  │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 192)              │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_27[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 256, 256,  │        520 │ conv2d_28[0][0]   │
# │                     │ 8)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,827,908 (29.86 MB)
#  Trainable params: 7,827,908 (29.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model_se.fit(
    train_gen,
    steps_per_epoch=len(train_img)//BATCH_SIZE,
    validation_data=val_gen,
    validation_steps=len(val_img)//BATCH_SIZE,
    epochs=EPOCHS
)

val_dice = []
val_iou = []
val_f1 = []

for i in range(len(val_img)//BATCH_SIZE):
    x_val, y_val = next(val_gen)
    y_pred = model_se.predict(x_val)
    y_pred = np.argmax(y_pred, axis=-1)
    
    for j in range(len(y_val)):
        true_mask = y_val[j]
        pred_mask = y_pred[j]
        dice, iou, f1 = calculate_metrics(true_mask, pred_mask, num_classes=len(index_to_color))
        val_dice.append(dice)
        val_iou.append(iou)
        val_f1.append(f1)

avg_val_dice = np.mean(val_dice, axis=0)
avg_val_iou = np.mean(val_iou, axis=0)
avg_val_f1 = np.mean(val_f1, axis=0)

class_names = list(index_to_color.keys())
for cls, name in enumerate(class_names):
    print(f"Class {name}:")
    print(f"  Dice: {avg_val_dice[cls]:.4f}")
    print(f"  IoU: {avg_val_iou[cls]:.4f}")
    print(f"  F1: {avg_val_f1[cls]:.4f}")
    print()

mIoU = np.mean(avg_val_iou)
avg_dice = np.mean(avg_val_dice)
print(f"mIoU: {mIoU:.4f}")
print(f"Average Dice: {avg_dice:.4f}")
# Out:
# Epoch 1/75
# W0000 00:00:1756734604.809405     104 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_combined_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.4161 - loss: 1.1470
# W0000 00:00:1756734677.016580     103 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_combined_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 91s 313ms/step - accuracy: 0.4164 - loss: 1.1466 - val_accuracy: 0.5546 - val_loss: 0.9810
# Epoch 2/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 300ms/step - accuracy: 0.5835 - loss: 0.9499 - val_accuracy: 0.5774 - val_loss: 0.9456
# Epoch 3/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.5734 - loss: 0.9494 - val_accuracy: 0.5732 - val_loss: 0.9406
# Epoch 4/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.5910 - loss: 0.9298 - val_accuracy: 0.5938 - val_loss: 0.9268
# Epoch 5/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.5840 - loss: 0.9366 - val_accuracy: 0.5796 - val_loss: 0.9158
# Epoch 6/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.5934 - loss: 0.9169 - val_accuracy: 0.5930 - val_loss: 0.9063
# Epoch 7/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.5909 - loss: 0.9232 - val_accuracy: 0.5951 - val_loss: 0.8947
# Epoch 8/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.5809 - loss: 0.9167 - val_accuracy: 0.5917 - val_loss: 0.9165
# Epoch 9/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6009 - loss: 0.9138 - val_accuracy: 0.5846 - val_loss: 0.9187
# Epoch 10/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 298ms/step - accuracy: 0.6036 - loss: 0.9075 - val_accuracy: 0.6035 - val_loss: 0.8938
# Epoch 11/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.5969 - loss: 0.9038 - val_accuracy: 0.6013 - val_loss: 0.9120
# Epoch 12/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6038 - loss: 0.8898 - val_accuracy: 0.6207 - val_loss: 0.8861
# Epoch 13/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6180 - loss: 0.8816 - val_accuracy: 0.6103 - val_loss: 0.8807
# Epoch 14/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6108 - loss: 0.8773 - val_accuracy: 0.6063 - val_loss: 0.8759
# Epoch 15/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 297ms/step - accuracy: 0.6078 - loss: 0.8736 - val_accuracy: 0.6096 - val_loss: 0.8723
# Epoch 16/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 297ms/step - accuracy: 0.6088 - loss: 0.8821 - val_accuracy: 0.5983 - val_loss: 0.8787
# Epoch 17/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.5992 - loss: 0.8842 - val_accuracy: 0.6054 - val_loss: 0.8613
# Epoch 18/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6247 - loss: 0.8559 - val_accuracy: 0.6062 - val_loss: 0.8595
# Epoch 19/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 298ms/step - accuracy: 0.6123 - loss: 0.8692 - val_accuracy: 0.6132 - val_loss: 0.8595
# Epoch 20/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6168 - loss: 0.8539 - val_accuracy: 0.6282 - val_loss: 0.8450
# Epoch 21/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6186 - loss: 0.8518 - val_accuracy: 0.6259 - val_loss: 0.8410
# Epoch 22/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6215 - loss: 0.8488 - val_accuracy: 0.6211 - val_loss: 0.8454
# Epoch 23/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6097 - loss: 0.8565 - val_accuracy: 0.6203 - val_loss: 0.8413
# Epoch 24/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 297ms/step - accuracy: 0.6370 - loss: 0.8323 - val_accuracy: 0.6240 - val_loss: 0.8430
# Epoch 25/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6325 - loss: 0.8319 - val_accuracy: 0.6445 - val_loss: 0.8298
# Epoch 26/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6410 - loss: 0.8208 - val_accuracy: 0.6385 - val_loss: 0.8173
# Epoch 27/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6375 - loss: 0.8251 - val_accuracy: 0.6308 - val_loss: 0.8222
# Epoch 28/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6364 - loss: 0.8270 - val_accuracy: 0.6412 - val_loss: 0.8118
# Epoch 29/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 73s 297ms/step - accuracy: 0.6514 - loss: 0.8068 - val_accuracy: 0.6297 - val_loss: 0.8265
# Epoch 30/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6355 - loss: 0.8225 - val_accuracy: 0.6328 - val_loss: 0.8118
# Epoch 31/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6256 - loss: 0.8289 - val_accuracy: 0.6468 - val_loss: 0.8098
# Epoch 32/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6402 - loss: 0.8160 - val_accuracy: 0.6413 - val_loss: 0.8127
# Epoch 33/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6436 - loss: 0.8098 - val_accuracy: 0.6668 - val_loss: 0.8154
# Epoch 34/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6455 - loss: 0.8081 - val_accuracy: 0.6479 - val_loss: 0.8094
# Epoch 35/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6391 - loss: 0.8226 - val_accuracy: 0.6304 - val_loss: 0.8142
# Epoch 36/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6465 - loss: 0.8045 - val_accuracy: 0.6396 - val_loss: 0.8095
# Epoch 37/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 297ms/step - accuracy: 0.6441 - loss: 0.8082 - val_accuracy: 0.6266 - val_loss: 0.8307
# Epoch 38/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6316 - loss: 0.8182 - val_accuracy: 0.6467 - val_loss: 0.8040
# Epoch 39/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6508 - loss: 0.8018 - val_accuracy: 0.6446 - val_loss: 0.8150
# Epoch 40/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6506 - loss: 0.7959 - val_accuracy: 0.6260 - val_loss: 0.8171
# Epoch 41/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6559 - loss: 0.7974 - val_accuracy: 0.6626 - val_loss: 0.7879
# Epoch 42/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6732 - loss: 0.7774 - val_accuracy: 0.6173 - val_loss: 0.8376
# Epoch 43/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 296ms/step - accuracy: 0.6581 - loss: 0.7944 - val_accuracy: 0.6209 - val_loss: 0.8372
# Epoch 44/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6514 - loss: 0.7891 - val_accuracy: 0.6296 - val_loss: 0.8170
# Epoch 45/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6662 - loss: 0.7837 - val_accuracy: 0.6578 - val_loss: 0.7871
# Epoch 46/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6585 - loss: 0.7874 - val_accuracy: 0.6500 - val_loss: 0.8044
# Epoch 47/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6579 - loss: 0.7871 - val_accuracy: 0.6451 - val_loss: 0.8112
# Epoch 48/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6477 - loss: 0.7979 - val_accuracy: 0.6487 - val_loss: 0.7975
# Epoch 49/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 293ms/step - accuracy: 0.6610 - loss: 0.7861 - val_accuracy: 0.6662 - val_loss: 0.7870
# Epoch 50/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6583 - loss: 0.7846 - val_accuracy: 0.6531 - val_loss: 0.8027
# Epoch 51/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6712 - loss: 0.7780 - val_accuracy: 0.6514 - val_loss: 0.7949
# Epoch 52/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 292ms/step - accuracy: 0.6678 - loss: 0.7769 - val_accuracy: 0.6601 - val_loss: 0.7907
# Epoch 53/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6707 - loss: 0.7777 - val_accuracy: 0.6748 - val_loss: 0.7707
# Epoch 54/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6755 - loss: 0.7692 - val_accuracy: 0.6821 - val_loss: 0.7628
# Epoch 55/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6834 - loss: 0.7577 - val_accuracy: 0.6583 - val_loss: 0.7979
# Epoch 56/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6687 - loss: 0.7761 - val_accuracy: 0.6470 - val_loss: 0.7996
# Epoch 57/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6675 - loss: 0.7729 - val_accuracy: 0.6535 - val_loss: 0.8002
# Epoch 58/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.6772 - loss: 0.7653 - val_accuracy: 0.6621 - val_loss: 0.7779
# Epoch 59/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6645 - loss: 0.7729 - val_accuracy: 0.6671 - val_loss: 0.7819
# Epoch 60/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6812 - loss: 0.7569 - val_accuracy: 0.6603 - val_loss: 0.7945
# Epoch 61/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6861 - loss: 0.7517 - val_accuracy: 0.6846 - val_loss: 0.7700
# Epoch 62/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6839 - loss: 0.7577 - val_accuracy: 0.6695 - val_loss: 0.7789
# Epoch 63/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6866 - loss: 0.7564 - val_accuracy: 0.6785 - val_loss: 0.7691
# Epoch 64/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6784 - loss: 0.7599 - val_accuracy: 0.6693 - val_loss: 0.7892
# Epoch 65/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6896 - loss: 0.7483 - val_accuracy: 0.6728 - val_loss: 0.7777
# Epoch 66/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6993 - loss: 0.7430 - val_accuracy: 0.6561 - val_loss: 0.7842
# Epoch 67/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6957 - loss: 0.7496 - val_accuracy: 0.6734 - val_loss: 0.7721
# Epoch 68/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.7077 - loss: 0.7365 - val_accuracy: 0.6756 - val_loss: 0.7770
# Epoch 69/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6974 - loss: 0.7423 - val_accuracy: 0.6737 - val_loss: 0.7792
# Epoch 70/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 293ms/step - accuracy: 0.6963 - loss: 0.7405 - val_accuracy: 0.6852 - val_loss: 0.7607
# Epoch 71/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 294ms/step - accuracy: 0.6965 - loss: 0.7394 - val_accuracy: 0.6964 - val_loss: 0.7692
# Epoch 72/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.6998 - loss: 0.7341 - val_accuracy: 0.6654 - val_loss: 0.7865
# Epoch 73/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 293ms/step - accuracy: 0.6990 - loss: 0.7340 - val_accuracy: 0.7038 - val_loss: 0.7497
# Epoch 74/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 72s 295ms/step - accuracy: 0.7040 - loss: 0.7321 - val_accuracy: 0.6688 - val_loss: 0.7725
# Epoch 75/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 71s 293ms/step - accuracy: 0.7020 - loss: 0.7337 - val_accuracy: 0.6726 - val_loss: 0.7725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# Class 0:
#   Dice: 0.7129
#   IoU: 0.6182
#   F1: 0.7129
#
# Class 1:
#   Dice: 0.0417
#   IoU: 0.0270
#   F1: 0.0417
#
# Class 2:
#   Dice: 0.0012
#   IoU: 0.0007
#   F1: 0.0012
#
# Class 3:
#   Dice: 0.1581
#   IoU: 0.1093
#   F1: 0.1581
#
# Class 4:
#   Dice: 0.0000
#   IoU: 0.0000
#   F1: 0.0000
#
# Class 5:
#   Dice: 0.4360
#   IoU: 0.3790
#   F1: 0.4360
#
# Class 6:
#   Dice: 0.0554
#   IoU: 0.0433
#   F1: 0.0554
#
# Class 7:
#   Dice: 0.1489
#   IoU: 0.1143
#   F1: 0.1489
#
# mIoU: 0.1615
# Average Dice: 0.1943

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 3, 3)
plt.bar(class_names, avg_val_dice)
plt.title('Dice Coefficient per Class')
plt.ylabel('Dice')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

plt.figure(figsize=(12, 4))

# IoU
plt.subplot(1, 2, 1)
plt.bar(class_names, avg_val_iou)
plt.title('IoU per Class')
plt.ylabel('IoU')
plt.xticks(rotation=45)

# F1
plt.subplot(1, 2, 2)
plt.bar(class_names, avg_val_f1)
plt.title('F1 Score per Class')
plt.ylabel('F1 Score')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
for i in np.random.choice(len(test_image_paths), 3):
    visualize_results(test_image_paths[i], test_mask_paths[i], model_se)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %% [markdown]
# UNET + CBAM

# %%
def channel_attention(input_feature, ratio=8):
    """Channel Attention Module"""
    channel = input_feature.shape[-1]
    
    # Shared MLP
    shared_layer_one = Dense(channel//ratio, activation='relu', use_bias=False)
    shared_layer_two = Dense(channel, use_bias=False)
    
    avg_pool = GlobalAveragePooling2D()(input_feature)    
    avg_pool = Reshape((1,1,channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=[1,2], keepdims=True))(input_feature)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    cbam_feature = Add()([avg_pool, max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)
    
    return Multiply()([input_feature, cbam_feature])

def spatial_attention(input_feature):
    """Spatial Attention Module"""
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(input_feature)
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    
    cbam_feature = Conv2D(1, (7,7), strides=1, padding='same', activation='sigmoid')(concat)
    
    return Multiply()([input_feature, cbam_feature])

def cbam_block(input_feature, ratio=8):
    """Complete CBAM block"""
    # Channel attention first
    channel_refined = channel_attention(input_feature, ratio)
    
    # Then spatial attention
    spatial_refined = spatial_attention(channel_refined)
    
    return spatial_refined

# %%
def unet_cbam_model(input_size=(256, 256, 3), num_classes=8):
    inputs = Input(input_size)
    
    c1 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(inputs)
    c1 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c1)
    cb1 = cbam_block(c1)  # Add CBAM after first conv block
    p1 = MaxPooling2D((2,2))(cb1)
    
    c2 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(p1)
    c2 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c2)
    cb2 = cbam_block(c2)  # Add CBAM
    p2 = MaxPooling2D((2,2))(cb2)
    
    c3 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(p2)
    c3 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c3)
    cb3 = cbam_block(c3)  # Add CBAM
    p3 = MaxPooling2D((2,2))(cb3)
    
    c4 = Conv2D(512, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(p3)
    c4 = Conv2D(512, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c4)
    cb4 = cbam_block(c4)  # Add CBAM
    
    u5 = UpSampling2D((2,2))(cb4)
    u5 = concatenate([u5, cb3])
    c5 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(u5)
    c5 = Conv2D(256, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c5)
    cb5 = cbam_block(c5)  # Add CBAM
    
    u6 = UpSampling2D((2,2))(cb5)
    u6 = concatenate([u6, cb2])
    c6 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(u6)
    c6 = Conv2D(128, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c6)
    cb6 = cbam_block(c6)  # Add CBAM
    
    u7 = UpSampling2D((2,2))(cb6)
    u7 = concatenate([u7, cb1])
    c7 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(u7)
    c7 = Conv2D(64, (3,3), activation='relu', padding='same',kernel_initializer = 'he_normal')(c7)
    cb7 = cbam_block(c7)  # Add CBAM
    
    outputs = Conv2D(num_classes, (1,1), activation='softmax')(cb7)
    
    model = Model(inputs=inputs, outputs=outputs)
    
    return model

# %%
model_cbam = unet_cbam_model(input_size=IMAGE_SIZE + (3,))

model_cbam.compile(optimizer=Adam(learning_rate=1e-4),
              loss=sparse_combined_loss,
             metrics=['accuracy']
             )
model_cbam.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │      1,792 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_30[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_31[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 64)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 1, 1, 64)  │          0 │ conv2d_31[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1, 1, 8)   │        512 │ reshape_4[0][0],  │
# │                     │                   │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1, 1, 64)  │        512 │ dense_8[0][0],    │
# │                     │                   │            │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 64)  │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_9[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 1, 1, 64)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 256, 256,  │          0 │ conv2d_31[0][0],  │
# │ (Multiply)          │ 64)               │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 256, 256,  │          0 │ multiply_4[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 256, 256,  │          0 │ multiply_4[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 256, 256,  │          0 │ lambda_1[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 256, 256,  │         99 │ concatenate_6[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 256, 256,  │          0 │ multiply_4[0][0], │
# │ (Multiply)          │ 64)               │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 128, 128,  │          0 │ multiply_5[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     73,856 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_33[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_34[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 1, 1, 128) │          0 │ conv2d_34[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1, 1, 16)  │      2,048 │ reshape_5[0][0],  │
# │                     │                   │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1, 1, 128) │      2,048 │ dense_10[0][0],   │
# │                     │                   │            │ dense_10[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 128) │          0 │ dense_11[0][0],   │
# │                     │                   │            │ dense_11[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1, 1, 128) │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 128, 128,  │          0 │ conv2d_34[0][0],  │
# │ (Multiply)          │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 128, 128,  │          0 │ multiply_6[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 128, 128,  │          0 │ multiply_6[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ lambda_4[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │         99 │ concatenate_7[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 128, 128,  │          0 │ multiply_6[0][0], │
# │ (Multiply)          │ 128)              │            │ conv2d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 64, 64,    │          0 │ multiply_7[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 64, 64,    │    295,168 │ max_pooling2d_7[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_36[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_37[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1, 256) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 1, 1, 256) │          0 │ conv2d_37[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 1, 1, 32)  │      8,192 │ reshape_6[0][0],  │
# │                     │                   │            │ lambda_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1, 1, 256) │      8,192 │ dense_12[0][0],   │
# │                     │                   │            │ dense_12[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 256) │          0 │ dense_13[0][0],   │
# │                     │                   │            │ dense_13[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1, 1, 256) │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 64, 64,    │          0 │ conv2d_37[0][0],  │
# │ (Multiply)          │ 256)              │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 64, 64, 1) │          0 │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 64, 64, 1) │          0 │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 64, 64, 2) │          0 │ lambda_7[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 64, 64, 1) │         99 │ concatenate_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 64, 64,    │          0 │ multiply_8[0][0], │
# │ (Multiply)          │ 256)              │            │ conv2d_38[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 32, 32,    │          0 │ multiply_9[0][0]  │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_8[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 32, 32,    │  2,359,808 │ conv2d_39[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ conv2d_40[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 1, 1, 512) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 1, 1, 512) │          0 │ conv2d_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 1, 1, 64)  │     32,768 │ reshape_7[0][0],  │
# │                     │                   │            │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 1, 1, 512) │     32,768 │ dense_14[0][0],   │
# │                     │                   │            │ dense_14[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 512) │          0 │ dense_15[0][0],   │
# │                     │                   │            │ dense_15[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1, 1, 512) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_10         │ (None, 32, 32,    │          0 │ conv2d_40[0][0],  │
# │ (Multiply)          │ 512)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_10 (Lambda)  │ (None, 32, 32, 1) │          0 │ multiply_10[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_11 (Lambda)  │ (None, 32, 32, 1) │          0 │ multiply_10[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 32, 32, 2) │          0 │ lambda_10[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 32, 32, 1) │         99 │ concatenate_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_11         │ (None, 32, 32,    │          0 │ multiply_10[0][0… │
# │ (Multiply)          │ 512)              │            │ conv2d_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 64, 64,    │          0 │ multiply_11[0][0] │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 64,    │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 768)              │            │ multiply_9[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 64, 64,    │  1,769,728 │ concatenate_10[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_42[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_43[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 256) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_12 (Lambda)  │ (None, 1, 1, 256) │          0 │ conv2d_43[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 1, 1, 32)  │      8,192 │ reshape_8[0][0],  │
# │                     │                   │            │ lambda_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1, 1, 256) │      8,192 │ dense_16[0][0],   │
# │                     │                   │            │ dense_16[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 256) │          0 │ dense_17[0][0],   │
# │                     │                   │            │ dense_17[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 1, 1, 256) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_12         │ (None, 64, 64,    │          0 │ conv2d_43[0][0],  │
# │ (Multiply)          │ 256)              │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_13 (Lambda)  │ (None, 64, 64, 1) │          0 │ multiply_12[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_14 (Lambda)  │ (None, 64, 64, 1) │          0 │ multiply_12[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 64, 64, 2) │          0 │ lambda_13[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 64, 64, 1) │         99 │ concatenate_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_13         │ (None, 64, 64,    │          0 │ multiply_12[0][0… │
# │ (Multiply)          │ 256)              │            │ conv2d_44[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 128, 128,  │          0 │ multiply_13[0][0] │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 128, 128,  │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 384)              │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 128, 128,  │    442,496 │ concatenate_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_45[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_46[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_15 (Lambda)  │ (None, 1, 1, 128) │          0 │ conv2d_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 1, 1, 16)  │      2,048 │ reshape_9[0][0],  │
# │                     │                   │            │ lambda_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 1, 1, 128) │      2,048 │ dense_18[0][0],   │
# │                     │                   │            │ dense_18[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 128) │          0 │ dense_19[0][0],   │
# │                     │                   │            │ dense_19[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 1, 1, 128) │          0 │ add_5[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_14         │ (None, 128, 128,  │          0 │ conv2d_46[0][0],  │
# │ (Multiply)          │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_16 (Lambda)  │ (None, 128, 128,  │          0 │ multiply_14[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_17 (Lambda)  │ (None, 128, 128,  │          0 │ multiply_14[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 128, 128,  │          0 │ lambda_16[0][0],  │
# │ (Concatenate)       │ 2)                │            │ lambda_17[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 128, 128,  │         99 │ concatenate_13[0… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_15         │ (None, 128, 128,  │          0 │ multiply_14[0][0… │
# │ (Multiply)          │ 128)              │            │ conv2d_47[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 256, 256,  │          0 │ multiply_15[0][0] │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 256, 256,  │          0 │ up_sampling2d_8[… │
# │ (Concatenate)       │ 192)              │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 256, 256,  │    110,656 │ concatenate_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_48[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_49[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_10          │ (None, 1, 1, 64)  │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_18 (Lambda)  │ (None, 1, 1, 64)  │          0 │ conv2d_49[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 1, 1, 8)   │        512 │ reshape_10[0][0], │
# │                     │                   │            │ lambda_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 1, 1, 64)  │        512 │ dense_20[0][0],   │
# │                     │                   │            │ dense_20[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 64)  │          0 │ dense_21[0][0],   │
# │                     │                   │            │ dense_21[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 1, 1, 64)  │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_16         │ (None, 256, 256,  │          0 │ conv2d_49[0][0],  │
# │ (Multiply)          │ 64)               │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_19 (Lambda)  │ (None, 256, 256,  │          0 │ multiply_16[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_20 (Lambda)  │ (None, 256, 256,  │          0 │ multiply_16[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 256, 256,  │          0 │ lambda_19[0][0],  │
# │ (Concatenate)       │ 2)                │            │ lambda_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 256, 256,  │         99 │ concatenate_15[0… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 256, 256,  │          0 │ multiply_16[0][0… │
# │ (Multiply)          │ 64)               │            │ conv2d_50[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 256, 256,  │        520 │ multiply_17[0][0] │
# │                     │ 8)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,892,605 (30.11 MB)
#  Trainable params: 7,892,605 (30.11 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model_cbam.fit(
    train_gen,
    steps_per_epoch=len(train_img)//BATCH_SIZE,
    validation_data=val_gen,
    validation_steps=len(val_img)//BATCH_SIZE,
    epochs=EPOCHS
)

val_dice = []
val_iou = []
val_f1 = []

for i in range(len(val_img)//BATCH_SIZE):
    x_val, y_val = next(val_gen)
    y_pred = model_cbam.predict(x_val)
    y_pred = np.argmax(y_pred, axis=-1)
    
    for j in range(len(y_val)):
        true_mask = y_val[j]
        pred_mask = y_pred[j]
        dice, iou, f1 = calculate_metrics(true_mask, pred_mask, num_classes=len(index_to_color))
        val_dice.append(dice)
        val_iou.append(iou)
        val_f1.append(f1)

avg_val_dice = np.mean(val_dice, axis=0)
avg_val_iou = np.mean(val_iou, axis=0)
avg_val_f1 = np.mean(val_f1, axis=0)

class_names = list(index_to_color.keys())
for cls, name in enumerate(class_names):
    print(f"Class {name}:")
    print(f"  Dice: {avg_val_dice[cls]:.4f}")
    print(f"  IoU: {avg_val_iou[cls]:.4f}")
    print(f"  F1: {avg_val_f1[cls]:.4f}")
    print()

mIoU = np.mean(avg_val_iou)
avg_dice = np.mean(avg_val_dice)
print(f"mIoU: {mIoU:.4f}")
print(f"Average Dice: {avg_dice:.4f}")
# Out:
# Epoch 1/75
# W0000 00:00:1756740058.027913     103 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_combined_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.4836 - loss: 1.2021
# W0000 00:00:1756740138.970019     103 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_combined_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 106s 338ms/step - accuracy: 0.4837 - loss: 1.2017 - val_accuracy: 0.5462 - val_loss: 1.0035
# Epoch 2/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 321ms/step - accuracy: 0.5579 - loss: 0.9770 - val_accuracy: 0.5854 - val_loss: 0.9343
# Epoch 3/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 319ms/step - accuracy: 0.5929 - loss: 0.9246 - val_accuracy: 0.6098 - val_loss: 0.8831
# Epoch 4/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6008 - loss: 0.9136 - val_accuracy: 0.5959 - val_loss: 0.9037
# Epoch 5/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6066 - loss: 0.8966 - val_accuracy: 0.6232 - val_loss: 0.8823
# Epoch 6/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6132 - loss: 0.8826 - val_accuracy: 0.5957 - val_loss: 0.8990
# Epoch 7/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 319ms/step - accuracy: 0.5990 - loss: 0.8947 - val_accuracy: 0.6227 - val_loss: 0.8763
# Epoch 8/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 319ms/step - accuracy: 0.6158 - loss: 0.8725 - val_accuracy: 0.6102 - val_loss: 0.8832
# Epoch 9/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 319ms/step - accuracy: 0.5937 - loss: 0.8889 - val_accuracy: 0.6192 - val_loss: 0.8592
# Epoch 10/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 319ms/step - accuracy: 0.6169 - loss: 0.8719 - val_accuracy: 0.6174 - val_loss: 0.8588
# Epoch 11/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6264 - loss: 0.8573 - val_accuracy: 0.6180 - val_loss: 0.8557
# Epoch 12/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6133 - loss: 0.8662 - val_accuracy: 0.6334 - val_loss: 0.8506
# Epoch 13/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 317ms/step - accuracy: 0.6239 - loss: 0.8629 - val_accuracy: 0.6282 - val_loss: 0.8574
# Epoch 14/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 318ms/step - accuracy: 0.6296 - loss: 0.8577 - val_accuracy: 0.6424 - val_loss: 0.8353
# Epoch 15/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 317ms/step - accuracy: 0.6199 - loss: 0.8579 - val_accuracy: 0.6521 - val_loss: 0.8257
# Epoch 16/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 319ms/step - accuracy: 0.6351 - loss: 0.8440 - val_accuracy: 0.6240 - val_loss: 0.8462
# Epoch 17/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 318ms/step - accuracy: 0.6352 - loss: 0.8414 - val_accuracy: 0.6376 - val_loss: 0.8479
# Epoch 18/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 317ms/step - accuracy: 0.6331 - loss: 0.8417 - val_accuracy: 0.6361 - val_loss: 0.8330
# Epoch 19/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6418 - loss: 0.8351 - val_accuracy: 0.6276 - val_loss: 0.8519
# Epoch 20/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 78s 318ms/step - accuracy: 0.6332 - loss: 0.8431 - val_accuracy: 0.6518 - val_loss: 0.8309
# Epoch 21/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 318ms/step - accuracy: 0.6514 - loss: 0.8228 - val_accuracy: 0.6468 - val_loss: 0.8335
# Epoch 22/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6492 - loss: 0.8271 - val_accuracy: 0.6365 - val_loss: 0.8406
# Epoch 23/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.6468 - loss: 0.8232 - val_accuracy: 0.6627 - val_loss: 0.8161
# Epoch 24/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6562 - loss: 0.8147 - val_accuracy: 0.6631 - val_loss: 0.8181
# Epoch 25/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6331 - loss: 0.8327 - val_accuracy: 0.6493 - val_loss: 0.8274
# Epoch 26/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 317ms/step - accuracy: 0.6581 - loss: 0.8076 - val_accuracy: 0.6334 - val_loss: 0.8483
# Epoch 27/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6519 - loss: 0.8172 - val_accuracy: 0.6576 - val_loss: 0.8257
# Epoch 28/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6569 - loss: 0.8120 - val_accuracy: 0.6439 - val_loss: 0.8207
# Epoch 29/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6540 - loss: 0.8139 - val_accuracy: 0.6346 - val_loss: 0.8245
# Epoch 30/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6571 - loss: 0.8132 - val_accuracy: 0.6369 - val_loss: 0.8323
# Epoch 31/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6573 - loss: 0.8011 - val_accuracy: 0.6415 - val_loss: 0.8292
# Epoch 32/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.6605 - loss: 0.8022 - val_accuracy: 0.6581 - val_loss: 0.8135
# Epoch 33/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6578 - loss: 0.8034 - val_accuracy: 0.6664 - val_loss: 0.8085
# Epoch 34/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6699 - loss: 0.7939 - val_accuracy: 0.6626 - val_loss: 0.8060
# Epoch 35/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 317ms/step - accuracy: 0.6717 - loss: 0.7964 - val_accuracy: 0.6613 - val_loss: 0.7994
# Epoch 36/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6519 - loss: 0.8010 - val_accuracy: 0.6469 - val_loss: 0.8225
# Epoch 37/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6642 - loss: 0.7918 - val_accuracy: 0.6390 - val_loss: 0.8181
# Epoch 38/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6711 - loss: 0.7785 - val_accuracy: 0.6550 - val_loss: 0.8092
# Epoch 39/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6749 - loss: 0.7808 - val_accuracy: 0.6604 - val_loss: 0.8115
# Epoch 40/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6484 - loss: 0.7999 - val_accuracy: 0.6725 - val_loss: 0.7928
# Epoch 41/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6650 - loss: 0.7838 - val_accuracy: 0.6587 - val_loss: 0.8070
# Epoch 42/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6576 - loss: 0.7855 - val_accuracy: 0.6654 - val_loss: 0.7947
# Epoch 43/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 317ms/step - accuracy: 0.6702 - loss: 0.7811 - val_accuracy: 0.6608 - val_loss: 0.7987
# Epoch 44/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6831 - loss: 0.7747 - val_accuracy: 0.6742 - val_loss: 0.7798
# Epoch 45/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6650 - loss: 0.7817 - val_accuracy: 0.6647 - val_loss: 0.8002
# Epoch 46/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6664 - loss: 0.7848 - val_accuracy: 0.6802 - val_loss: 0.7850
# Epoch 47/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.6770 - loss: 0.7712 - val_accuracy: 0.6829 - val_loss: 0.7796
# Epoch 48/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6896 - loss: 0.7591 - val_accuracy: 0.6733 - val_loss: 0.7938
# Epoch 49/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.7034 - loss: 0.7534 - val_accuracy: 0.6968 - val_loss: 0.7748
# Epoch 50/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6902 - loss: 0.7569 - val_accuracy: 0.6722 - val_loss: 0.8082
# Epoch 51/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6913 - loss: 0.7597 - val_accuracy: 0.6483 - val_loss: 0.8020
# Epoch 52/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6833 - loss: 0.7583 - val_accuracy: 0.6903 - val_loss: 0.7639
# Epoch 53/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6990 - loss: 0.7515 - val_accuracy: 0.6865 - val_loss: 0.7709
# Epoch 54/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6965 - loss: 0.7535 - val_accuracy: 0.6674 - val_loss: 0.7908
# Epoch 55/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6967 - loss: 0.7462 - val_accuracy: 0.6509 - val_loss: 0.8006
# Epoch 56/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.6964 - loss: 0.7434 - val_accuracy: 0.6903 - val_loss: 0.7615
# Epoch 57/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.6917 - loss: 0.7549 - val_accuracy: 0.6897 - val_loss: 0.7724
# Epoch 58/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.6884 - loss: 0.7511 - val_accuracy: 0.6712 - val_loss: 0.7820
# Epoch 59/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6988 - loss: 0.7412 - val_accuracy: 0.6607 - val_loss: 0.7858
# Epoch 60/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6849 - loss: 0.7559 - val_accuracy: 0.6669 - val_loss: 0.7867
# Epoch 61/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6978 - loss: 0.7436 - val_accuracy: 0.6921 - val_loss: 0.7698
# Epoch 62/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.6955 - loss: 0.7416 - val_accuracy: 0.6825 - val_loss: 0.7740
# Epoch 63/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.7101 - loss: 0.7323 - val_accuracy: 0.6782 - val_loss: 0.7774
# Epoch 64/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.7230 - loss: 0.7125 - val_accuracy: 0.7045 - val_loss: 0.7493
# Epoch 65/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.7119 - loss: 0.7178 - val_accuracy: 0.6848 - val_loss: 0.7803
# Epoch 66/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.7305 - loss: 0.7056 - val_accuracy: 0.6843 - val_loss: 0.7688
# Epoch 67/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 316ms/step - accuracy: 0.7128 - loss: 0.7234 - val_accuracy: 0.6886 - val_loss: 0.7652
# Epoch 68/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.7208 - loss: 0.7222 - val_accuracy: 0.6929 - val_loss: 0.7720
# Epoch 69/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 76s 313ms/step - accuracy: 0.7199 - loss: 0.7177 - val_accuracy: 0.6530 - val_loss: 0.8126
# Epoch 70/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 76s 313ms/step - accuracy: 0.7210 - loss: 0.7249 - val_accuracy: 0.7148 - val_loss: 0.7449
# Epoch 71/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.7326 - loss: 0.7016 - val_accuracy: 0.6938 - val_loss: 0.7695
# Epoch 72/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 76s 312ms/step - accuracy: 0.7286 - loss: 0.7105 - val_accuracy: 0.6842 - val_loss: 0.7719
# Epoch 73/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 315ms/step - accuracy: 0.7248 - loss: 0.7143 - val_accuracy: 0.6913 - val_loss: 0.7489
# Epoch 74/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 76s 313ms/step - accuracy: 0.7095 - loss: 0.7202 - val_accuracy: 0.6977 - val_loss: 0.7514
# Epoch 75/75
# 244/244 ━━━━━━━━━━━━━━━━━━━━ 77s 314ms/step - accuracy: 0.7351 - loss: 0.6993 - val_accuracy: 0.7007 - val_loss: 0.7683
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Class 0:
#   Dice: 0.7400
#   IoU: 0.6538
#   F1: 0.7400
#
# Class 1:
#   Dice: 0.0363
#   IoU: 0.0261
#   F1: 0.0363
#
# Class 2:
#   Dice: 0.0018
#   IoU: 0.0013
#   F1: 0.0018
#
# Class 3:
#   Dice: 0.1439
#   IoU: 0.1006
#   F1: 0.1439
#
# Class 4:
#   Dice: 0.0000
#   IoU: 0.0000
#   F1: 0.0000
#
# Class 5:
#   Dice: 0.4256
#   IoU: 0.3681
#   F1: 0.4256
#
# Class 6:
#   Dice: 0.0261
#   IoU: 0.0193
#   F1: 0.0261
#
# Class 7:
#   Dice: 0.1082
#   IoU: 0.0846
#   F1: 0.1082
#
# mIoU: 0.1567
# Average Dice: 0.1853

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 3, 3)
plt.bar(class_names, avg_val_dice)
plt.title('Dice Coefficient per Class')
plt.ylabel('Dice')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

plt.figure(figsize=(12, 4))

# IoU
plt.subplot(1, 2, 1)
plt.bar(class_names, avg_val_iou)
plt.title('IoU per Class')
plt.ylabel('IoU')
plt.xticks(rotation=45)

# F1
plt.subplot(1, 2, 2)
plt.bar(class_names, avg_val_f1)
plt.title('F1 Score per Class')
plt.ylabel('F1 Score')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
for i in np.random.choice(len(test_image_paths), 3):
    visualize_results(test_image_paths[i], test_mask_paths[i], model_cbam)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
